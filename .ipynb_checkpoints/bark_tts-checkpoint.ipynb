# %%
# !pip install git+https://github.com/suno-ai/bark.git
# Out:
# Collecting git+https://github.com/suno-ai/bark.git
#   Cloning https://github.com/suno-ai/bark.git to /tmp/pip-req-build-yj6jkdym
#   Running command git clone --filter=blob:none --quiet https://github.com/suno-ai/bark.git /tmp/pip-req-build-yj6jkdym
#   Resolved https://github.com/suno-ai/bark.git to commit f4f32d4cd480dfec1c245d258174bc9bde3c2148
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tokenizers in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.19.1)
# Requirement already satisfied: encodec in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.1.1)
# Requirement already satisfied: transformers in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (4.44.2)
# Requirement already satisfied: scipy in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.14.1)
# Requirement already satisfied: boto3 in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (1.35.8)
# Requirement already satisfied: funcy in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.0)
# Requirement already satisfied: numpy in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.1.0)
# Requirement already satisfied: huggingface-hub>=0.14.1 in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (0.24.6)
# Requirement already satisfied: torch in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (2.4.0)
# Requirement already satisfied: tqdm in ./.venv/lib/python3.10/site-packages (from suno-bark==0.0.1a0) (4.66.5)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (6.0.2)
# Requirement already satisfied: filelock in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.15.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (4.12.2)
# Requirement already satisfied: packaging>=20.9 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (24.1)
# Requirement already satisfied: requests in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2.32.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.10/site-packages (from huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2024.6.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in ./.venv/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (0.10.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in ./.venv/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (1.0.1)
# Requirement already satisfied: botocore<1.36.0,>=1.35.8 in ./.venv/lib/python3.10/site-packages (from boto3->suno-bark==0.0.1a0) (1.35.8)
# Requirement already satisfied: einops in ./.venv/lib/python3.10/site-packages (from encodec->suno-bark==0.0.1a0) (0.8.0)
# Requirement already satisfied: torchaudio in ./.venv/lib/python3.10/site-packages (from encodec->suno-bark==0.0.1a0) (2.4.0)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.4.5.107)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.1.4)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (12.1.3.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (12.1.105)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (10.3.2.106)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (12.1.105)
# Requirement already satisfied: sympy in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (1.13.2)
# Requirement already satisfied: networkx in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (9.1.0.70)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (12.1.105)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (11.0.2.54)
# Requirement already satisfied: triton==3.0.0 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (3.0.0)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.venv/lib/python3.10/site-packages (from torch->suno-bark==0.0.1a0) (2.20.5)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.venv/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->suno-bark==0.0.1a0) (12.6.20)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.10/site-packages (from transformers->suno-bark==0.0.1a0) (0.4.4)
# Requirement already satisfied: regex!=2019.12.17 in ./.venv/lib/python3.10/site-packages (from transformers->suno-bark==0.0.1a0) (2024.7.24)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in ./.venv/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.8->boto3->suno-bark==0.0.1a0) (2.2.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in ./.venv/lib/python3.10/site-packages (from botocore<1.36.0,>=1.35.8->boto3->suno-bark==0.0.1a0) (2.9.0.post0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.10/site-packages (from jinja2->torch->suno-bark==0.0.1a0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.14.1->suno-bark==0.0.1a0) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.venv/lib/python3.10/site-packages (from sympy->torch->suno-bark==0.0.1a0) (1.3.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.8->boto3->suno-bark==0.0.1a0) (1.16.0)

# %%
# !nvidia-smi
# Out:
# Sun Sep  1 18:34:41 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.02              Driver Version: 560.94         CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 Ti     On  |   00000000:01:00.0  On |                  N/A |
# | 32%   53C    P0             48W /  200W |     475MiB /   8192MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A        34      G   /Xwayland                                   N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import nltk
import os

# Set NLTK data path to the directory within the virtual environment
nltk_data_dir = os.path.join(os.getcwd(), '.venv', 'nltk_data')
nltk.data.path.append(nltk_data_dir)

# Download the 'punkt' tokenizer to this directory
nltk.download('punkt', download_dir=nltk_data_dir)
nltk.download('punkt_tab', download_dir=nltk_data_dir)
# Out:
# [nltk_data] Downloading package punkt to /home/csi/bark-
# [nltk_data]     tts/.venv/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/csi/bark-
# [nltk_data]     tts/.venv/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
import os

from bark import generate_audio, preload_models, SAMPLE_RATE
import time
from scipy.io.wavfile import write as write_wav

#import naming_saving as ns
#import split

# %%
from scipy.io.wavfile import write as write_wav

def __get_unique_filename(base_name, directory):
    """Generate a unique filename by appending an incrementing number."""
    # Check if the directory exists
    if not os.path.isdir(directory):
        raise ValueError(f"The directory {directory} does not exist.")

    # Get a list of existing filenames in the directory
    existing_files = os.listdir(directory)

    # Extract existing numbers from filenames
    existing_numbers = []
    for filename in existing_files:
        if filename.startswith(base_name) and filename[len(base_name)].isdigit():
            try:
                number = int(filename[len(base_name):].split('.')[0])
                existing_numbers.append(number)
            except ValueError:
                continue

    # Find the highest number and increment
    highest_number = max(existing_numbers, default=0)
    next_number = highest_number + 1

    unique_filename = f"{base_name}{next_number}"

    return unique_filename

def save_text_file_with_unique_name(content, base_name, directory, extension='txt'):
    """Save a text file with a unique name in the specified directory."""
    # Generate a unique filename
    filename = __get_unique_filename(base_name, directory) + f".{extension}"

    # Full path to save the file
    filepath = os.path.join(directory, filename)

    # Save the file
    with open(filepath, 'w') as file:
        file.write(content)

    return filepath

def save_wav_file_with_unique_name(audio_array, base_name, directory, sample_rate):
    """Save a wav file with a unique name in the specified directory."""

    # Generate a unique filename
    filename = __get_unique_filename(base_name, directory) + ".wav"

    # Full path to save the file
    filepath = os.path.join(directory, filename)

    write_wav(filepath, sample_rate, audio_array)

    return filepath

# %%
import nltk
from typing import List, Union

def split_text_to_chunks2(text_or_file: Union[str, object], max_chars: int = 200, overlap: int = 50) -> List[str]:
    """
    Split text into chunks of approximately max_chars length, respecting sentence boundaries where possible.
    
    Args:
    text_or_file (str or file-like object): The input text or a file object to read from.
    max_chars (int): Maximum number of characters per chunk.
    overlap (int): Number of characters to overlap between chunks.
    
    Returns:
    List[str]: A list of text chunks.
    """
    if hasattr(text_or_file, 'read'):
        text = text_or_file.read()
    else:
        text = text_or_file

    sentences = nltk.sent_tokenize(text)
    chunks = []
    current_chunk = ""
    
    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_chars:
            current_chunk += " " + sentence
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            
            # If the sentence is longer than max_chars, split it
            if len(sentence) > max_chars:
                words = sentence.split()
                temp_chunk = ""
                for word in words:
                    if len(temp_chunk) + len(word) <= max_chars:
                        temp_chunk += " " + word
                    else:
                        chunks.append(temp_chunk.strip())
                        temp_chunk = word
                if temp_chunk:
                    current_chunk = temp_chunk
            else:
                current_chunk = sentence

    if current_chunk:
        chunks.append(current_chunk.strip())

    # Add overlap
    if overlap > 0:
        overlapped_chunks = []
        for i, chunk in enumerate(chunks):
            if i > 0:
                start = max(0, len(chunk) - overlap)
                chunk = chunks[i-1][-overlap:] + " " + chunk
            if i < len(chunks) - 1:
                end = min(len(chunk), len(chunk) - overlap)
                chunk = chunk[:end]
            overlapped_chunks.append(chunk.strip())
        chunks = overlapped_chunks

    return chunks

# %%
# Use split_text_to_chunks to divide any text into chunk

# %%
# Example usage
with open(file_path, 'r') as text_file:
    chunks = split_text_to_chunks2(text_file, max_chars=90, overlap=0)
    for i, chunk in enumerate(chunks):
        print(f"Chunk {i + 1}: {chunk}\n")
# Out:
# Chunk 1: Précis of Cognitive Gadgets: The Cultural Evolution of Thinking Abstract Cognitive gadgets
#
# Chunk 2: are distinctively human cognitive mechanisms – such as imitation, mind reading, and
#
# Chunk 3: language – that have been shaped by cultural rather than genetic evolution.
#
# Chunk 4: New gadgets emerge, not by genetic mutation, but by innovations in cognitive development;
#
# Chunk 5: they are specialised cognitive mechanisms built by general cognitive mechanisms using
#
# Chunk 6: information from the sociocultural environment.
#
# Chunk 7: Innovations are passed on to subsequent generations, not by DNA replication, but through
#
# Chunk 8: social learning: People with new cognitive mechanisms pass them on to others through social
#
# Chunk 9: interaction.
#
# Chunk 10: Some of the new mechanisms, like literacy, have spread through human populations, while
#
# Chunk 11: others have died out, because the holders had more students, not just more babies.
#
# Chunk 12: The cognitive gadgets hypothesis is developed through four case studies, drawing on
#
# Chunk 13: evidence from comparative and developmental psychology, experimental psychology, and
#
# Chunk 14: cognitive neuroscience.
#
# Chunk 15: The framework employed – cultural evolutionary psychology, a descendant of evolutionary
#
# Chunk 16: psychology and cultural evolutionary theory – addresses parallel issues across the
#
# Chunk 17: cognitive and behavioural sciences.
#
# Chunk 18: In common with evolutionary developmental biology (evo-devo) and the extended evolutionary
#
# Chunk 19: synthesis, cultural evolutionary psychology underlines the importance of developmental
#
# Chunk 20: processes and environmental factors in the emergence of human cognition.
#
# Chunk 21: In common with computational approaches (deep learning, predictive coding, hierarchical
#
# Chunk 22: reinforcement learning, causal modelling), it emphasises the power of general-purpose
#
# Chunk 23: mechanisms of learning.
#
# Chunk 24: Cultural evolutionary psychology, however, also challenges use of the behavioural gambit
#
# Chunk 25: in economics and behavioural ecology, and rejects the view that human minds are composed of
#
# Chunk 26: “innate modules” or “cognitive instincts.”

# %%
import nltk
from typing import List, Union

def split_text_to_chunks(text_or_file: Union[str, object], min_chars: int = 100, max_chars: int = 200) -> List[str]:
    """
    Split text into chunks respecting sentence boundaries, with size constraints.
    
    Args:
    text_or_file (str or file-like object): The input text or a file object to read from.
    min_chars (int): Minimum number of characters per chunk.
    max_chars (int): Maximum number of characters per chunk.
    
    Returns:
    List[str]: A list of text chunks.
    """
    if hasattr(text_or_file, 'read'):
        text = text_or_file.read()
    else:
        text = text_or_file

    sentences = nltk.sent_tokenize(text)
    chunks = []
    current_chunk = ""
    
    for sentence in sentences:
        if len(current_chunk) + len(sentence) <= max_chars:
            current_chunk += " " + sentence
        else:
            if current_chunk:
                chunks.append(current_chunk.strip())
            current_chunk = sentence

        # If the current chunk is longer than max_chars, we need to split it
        while len(current_chunk) > max_chars:
            split_point = current_chunk.rfind(' ', min_chars, max_chars)
            if split_point == -1:  # If we can't find a space, we'll have to split mid-word
                split_point = max_chars
            chunks.append(current_chunk[:split_point].strip())
            current_chunk = current_chunk[split_point:].strip()

    # Add any remaining text as the last chunk
    if current_chunk:
        chunks.append(current_chunk.strip())

    # Merge short chunks with neighbors
    i = 0
    while i < len(chunks) - 1:
        if len(chunks[i]) < min_chars:
            if len(chunks[i] + " " + chunks[i+1]) <= max_chars:
                chunks[i] += " " + chunks[i+1]
                chunks.pop(i+1)
            else:
                i += 1
        else:
            i += 1

    return chunks

'''
# Example usage
text = "Your long text here. It can contain multiple sentences. Some sentences might be very long, while others could be quite short. We want to make sure that we respect sentence boundaries as much as possible, while also ensuring that our chunks are neither too short nor too long."
chunks = split_text_to_chunks(text, min_chars=100, max_chars=200)
for i, chunk in enumerate(chunks):
    print(f"Chunk {i + 1} ({len(chunk)} chars): {chunk}\n")

'''
# Out:
# '\n# Example usage\ntext = "Your long text here. It can contain multiple sentences. Some sentences might be very long, while others could be quite short. We want to make sure that we respect sentence boundaries as much as possible, while also ensuring that our chunks are neither too short nor too long."\nchunks = split_text_to_chunks(text, min_chars=100, max_chars=200)\nfor i, chunk in enumerate(chunks):\n    print(f"Chunk {i + 1} ({len(chunk)} chars): {chunk}\n")\n\n'

# %%
# Example usage
with open(file_path, 'r') as text_file:
    chunks = split_text_to_chunks(text_file, min_chars=90, max_chars=200)
    for i, chunk in enumerate(chunks):
        print(f"Chunk {i + 1}: {chunk}\n")

# %%
history_promtps_pt = [
    "v2/pt_speaker_0",
    "v2/pt_speaker_1",
    "v2/pt_speaker_2",
    "v2/pt_speaker_3",
    "v2/pt_speaker_4",
    "v2/pt_speaker_5",
    "v2/pt_speaker_6",
    "v2/pt_speaker_7",
    "v2/pt_speaker_8",
    "v2/pt_speaker_9"
]

history_promtps_en =[
    "v2/en_speaker_0",
    "v2/en_speaker_1",
    "v2/en_speaker_2",
    "v2/en_speaker_3",
    "v2/en_speaker_4",
    "v2/en_speaker_5",
    "v2/en_speaker_6",
    "v2/en_speaker_7",
    "v2/en_speaker_8",
    "v2/en_speaker_9",
]

# %%
#os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ["SUNO_USE_SMALL_MODELS"] = "False"
#os.environ["SUNO_OFFLOAD_CPU"] = "False"

preload_models()

# %%
import numpy as np
import soundfile as sf
import os

file_path = "inputs/sd.md"
base_output_name = "sd3"
output_directory = "outputs"
output_file_name = f"{base_output_name}.wav"
output_file_path = os.path.join(output_directory, output_file_name)

# Create the output directory if it doesn't exist
os.makedirs(output_directory, exist_ok=True)

# Open the output file in 'write' mode
with sf.SoundFile(output_file_path, mode='w', samplerate=SAMPLE_RATE, channels=1) as file:
    with open(file_path, 'r') as text_file:
        #chunks = split_text_to_chunks(text_file, max_chars=90, overlap=0)
        chunks = split_text_to_chunks(text_file, min_chars=20, max_chars=90)

        t0 = time.time()
        total_duration = 0
        for idx, chunk in enumerate(chunks):
            print(f"Chunk {idx + 1}: {chunk}")
            audio_array = generate_audio(chunk, history_prompt=history_promtps_en[0])
            audio_duration_s = len(audio_array) / SAMPLE_RATE
            total_duration += audio_duration_s
            print(f"Generated {audio_duration_s:.2f}s of audio")

            # Write the audio data to the file
            file.write(audio_array)

        generation_duration_s = time.time() - t0

    print(f"Took {generation_duration_s:.2f}s to generate {total_duration:.2f}s of audio")
# Out:
# Chunk 1: Précis of Cognitive Gadgets: The Cultural Evolution of Thinking
#
# Abstract
# Cognitive
#   0%|                                                                                                                                              | 0/768 [00:00<?, ?it/s]
#   1%|█▌                                                                                                                                    | 9/768 [00:00<00:08, 86.41it/s]
#   3%|███▍                                                                                                                                 | 20/768 [00:00<00:07, 95.40it/s]
#   4%|█████▌                                                                                                                              | 32/768 [00:00<00:07, 102.50it/s]
#   6%|███████▍                                                                                                                            | 43/768 [00:00<00:07, 103.13it/s]
#   7%|█████████▎                                                                                                                          | 54/768 [00:00<00:06, 103.50it/s]
#   8%|███████████▏                                                                                                                        | 65/768 [00:00<00:06, 104.73it/s]
#  10%|█████████████                                                                                                                       | 76/768 [00:00<00:06, 105.16it/s]
#  11%|██████████████▉                                                                                                                     | 87/768 [00:00<00:06, 105.42it/s]
#  13%|████████████████▊                                                                                                                   | 98/768 [00:00<00:06, 106.48it/s]
78it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 24
#      22 for idx, chunk in enumerate(chunks):
#      23     print(f"Chunk {idx + 1}: {chunk}")
# ---> 24     audio_array = generate_audio(chunk, history_prompt=history_promtps_en[0])
#      25     audio_duration_s = len(audio_array) / SAMPLE_RATE
#      26     total_duration += audio_duration_s
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/bark/api.py:113, in generate_audio(text, history_prompt, text_temp, waveform_temp, silent, output_full)
#      94 """Generate audio array from input text.
#      95
#      96 Args:
#    (...)
#     105     numpy audio array at sample frequency 24khz
#     106 """
#     107 semantic_tokens = text_to_semantic(
#     108     text,
#     109     history_prompt=history_prompt,
#     110     temp=text_temp,
#     111     silent=silent,
#     112 )
# --> 113 out = semantic_to_waveform(
#     114     semantic_tokens,
#     115     history_prompt=history_prompt,
#     116     temp=waveform_temp,
#     117     silent=silent,
#     118     output_full=output_full,
#     119 )
#     120 if output_full:
#     121     full_generation, audio_arr = out
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/bark/api.py:54, in semantic_to_waveform(semantic_tokens, history_prompt, temp, silent, output_full)
#      35 def semantic_to_waveform(
#      36     semantic_tokens: np.ndarray,
#      37     history_prompt: Optional[Union[Dict, str]] = None,
#    (...)
#      40     output_full: bool = False,
#      41 ):
#      42     """Generate audio array from semantic input.
#      43
#      44     Args:
#    (...)
#      52         numpy audio array at sample frequency 24khz
#      53     """
# ---> 54     coarse_tokens = generate_coarse(
#      55         semantic_tokens,
#      56         history_prompt=history_prompt,
#      57         temp=temp,
#      58         silent=silent,
#      59         use_kv_caching=True
#      60     )
#      61     fine_tokens = generate_fine(
#      62         coarse_tokens,
#      63         history_prompt=history_prompt,
#      64         temp=0.5,
#      65     )
#      66     audio_arr = codec_decode(fine_tokens)
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/bark/generation.py:646, in generate_coarse(x_semantic, history_prompt, temp, top_k, top_p, silent, max_coarse_history, sliding_window_len, use_kv_caching)
#     643 else:
#     644     x_input = x_in
# --> 646 logits, kv_cache = model(x_input, use_cache=use_kv_caching, past_kv=kv_cache)
#     647 logit_start_idx = (
#     648     SEMANTIC_VOCAB_SIZE + (1 - int(is_major_step)) * CODEBOOK_SIZE
#     649 )
#     650 logit_end_idx = (
#     651     SEMANTIC_VOCAB_SIZE + (2 - int(is_major_step)) * CODEBOOK_SIZE
#     652 )
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1553, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1551     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552 else:
# -> 1553     return self._call_impl(*args, **kwargs)
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1562, in Module._call_impl(self, *args, **kwargs)
#    1557 # If we don't have any hooks, we want to skip the rest of the logic in
#    1558 # this function, and just call forward.
#    1559 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1560         or _global_backward_pre_hooks or _global_backward_hooks
#    1561         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562     return forward_call(*args, **kwargs)
#    1564 try:
#    1565     result = None
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/bark/model.py:208, in GPT.forward(self, idx, merge_context, past_kv, position_ids, use_cache)
#     205 new_kv = () if use_cache else None
#     207 for i, (block, past_layer_kv) in enumerate(zip(self.transformer.h, past_kv)):
# --> 208     x, kv = block(x, past_kv=past_layer_kv, use_cache=use_cache)
#     210     if use_cache:
#     211         new_kv = new_kv + (kv,)
#
# File ~/bark-tts/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1549, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1546             tracing_state.pop_scope()
#    1547     return result
# -> 1549 def _wrapped_call_impl(self, *args, **kwargs):
#    1550     if self._compiled_call_impl is not None:
#    1551         return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#
# KeyboardInterrupt:
